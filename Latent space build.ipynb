# %%
from src.LatentSpace import LatentSpace
import matplotlib.pyplot as plt

# %%
latent_space = LatentSpace(autoencoder_path='data/autoencoder_100k_512f_mel_128/',
                        image_dir='data/Spotify/comp_pngs/',
                        tracks_feather_path='data/all_tracks.feather'
                        )
# Out:
# Found 278326 files for Generator set

# %%
latent_space.build()
# Out:
# Getting predictions from autoencoder...
# [============================================================>] 8697 / 8697
#
# 47.6 minutes elapsed
# Building tracks dataframe...

# %%
latent_space.save('data/latent_space_save_2/')
latent_space.load('data/latent_space_save_2')

# %%
latent_space.plot_reconstruction(185895)
latent_space.plot_reconstruction(167585)
# Out:
# 2022-08-16 11:48:20.929804: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
latent_space.tracks[latent_space.tracks.artist_name.str.contains('Michael Jackson')][['track_name','artist_name']]
# Out:
#                                       track_name      artist_name
# 31331   The Way You Make Me Feel - 2012 Remaster  Michael Jackson
# 92958            Smooth Criminal - 2012 Remaster  Michael Jackson
# 146708            Don't Stop 'Til You Get Enough  Michael Jackson
# 185895                               Billie Jean  Michael Jackson
# 206138                       Bad - 2012 Remaster  Michael Jackson

# %%
latent_space.artists
# Out:
#                      latent_0  latent_1  latent_2  latent_3  latent_4  \
# artist_name
# !!!                 -0.093092  0.273635 -0.359922  0.055348 -0.745507
# "Weird Al" Yankovic  0.341545  0.226364 -0.431828 -0.737806  1.033889
# #1 Dads              0.688585 -0.325864 -0.403679 -0.171223  0.147612
# #90s Update         -0.601853  0.760909 -0.229960  0.272182  0.333696
# #M P L S             0.057898 -0.027478 -0.111383 -0.339202  0.490447
# ...                       ...       ...       ...       ...       ...
# 트로트 가수들             -0.055655  0.135593 -0.545033  0.102071  0.173445
# 파니핑크                 0.833407 -0.240428 -0.082421  0.621003 -0.030435
# 패티김                  1.555425  0.157135  0.382276  0.166312 -1.162988
# 푸른새벽                 0.102385 -0.881505  0.437966  0.131330 -1.489592
# 플라워                  0.573591  0.466193  0.408668 -0.369388  0.914828
#
#                      latent_5  latent_6  latent_7  latent_8  latent_9  ...  \
# artist_name                                                            ...
# !!!                 -0.505306  0.388119 -0.094968 -0.160234 -0.064491  ...
# "Weird Al" Yankovic -0.306828 -0.000568  0.289829 -0.303757 -0.988815  ...
# #1 Dads             -0.539949 -0.416179  0.186194 -0.169721 -0.307046  ...
# #90s Update          0.217613  0.348038  0.308312 -0.258377  0.954199  ...
# #M P L S             0.264413  0.091633 -0.237328  1.008620 -0.354147  ...
# ...                       ...       ...       ...       ...       ...  ...
# 트로트 가수들             -0.433332 -0.236751 -0.162848 -0.394171 -0.139164  ...
# 파니핑크                -0.594916  0.105251 -0.840222  0.375992 -0.822308  ...
# 패티김                 -1.223127 -0.342458  0.060412  0.549998  0.474238  ...
# 푸른새벽                -0.355674 -0.685026  0.286568 -0.247291  0.436201  ...
# 플라워                  0.337832 -1.805027  0.210605  0.800312 -0.055374  ...
#
#                      latent_118  latent_119  latent_120  latent_121  \
# artist_name
# !!!                    0.381984    0.060424   -0.529038    0.032527
# "Weird Al" Yankovic    0.109830    1.422638    0.837454   -0.444964
# #1 Dads               -0.391773    0.616138   -0.160558   -0.380312
# #90s Update            0.522312    0.627956   -0.578197   -0.442360
# #M P L S              -0.104905    0.050863    0.211532    0.627698
# ...                         ...         ...         ...         ...
# 트로트 가수들               -0.565690    0.190121    0.009241    0.294647
# 파니핑크                  -0.351878    0.986316    0.467274    0.288985
# 패티김                   -1.825267    0.410207   -1.016812    0.375702
# 푸른새벽                  -0.625353    0.396986   -1.407856    0.013190
# 플라워                   -0.307995   -0.080116   -0.245216   -0.973371
#
#                      latent_122  latent_123  latent_124  latent_125  \
# artist_name
# !!!                    0.187413   -0.242615    0.271059    0.230804
# "Weird Al" Yankovic    0.005258    0.681249    0.206787    0.998370
# #1 Dads               -0.460960   -0.029136   -0.212427   -0.029432
# #90s Update            0.668299   -0.195950   -0.211039    0.324261
# #M P L S               0.401851    0.380693    0.395675    0.904276
# ...                         ...         ...         ...         ...
# 트로트 가수들                0.272876   -0.043947    0.573592    0.344783
# 파니핑크                  -0.055140   -0.265303   -0.706402    0.142739
# 패티김                   -0.374664    0.365698   -0.586565    0.210377
# 푸른새벽                  -0.509009    0.872610   -0.981351   -0.136199
# 플라워                   -0.126780   -0.400502    0.779326    0.627357
#
#                      latent_126  latent_127
# artist_name
# !!!                   -0.013089   -0.462809
# "Weird Al" Yankovic   -0.230414    0.246917
# #1 Dads                0.101394   -0.097789
# #90s Update            0.021071    0.713074
# #M P L S               0.081716    0.238920
# ...                         ...         ...
# 트로트 가수들               -0.505729   -0.661723
# 파니핑크                  -0.607964   -0.386149
# 패티김                   -0.346670    0.012528
# 푸른새벽                  -0.477512    0.471264
# 플라워                    0.172739   -0.274737
#
# [62542 rows x 128 columns]

# %%
seed = 185895

display(latent_space.get_similar_tracks_by_index(seed, similarity_measure='cosine'))
#display(latent_space.get_similar_artists_by_index(seed, similarity_measure='cosine'))
display(latent_space.get_similar_genres_by_index(seed, similarity_measure='euclidean'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 seed = 185895
# ----> 3 display(latent_space.get_similar_tracks_by_index(seed, similarity_measure='cosine'))
#       4 #display(latent_space.get_similar_artists_by_index(seed, similarity_measure='cosine'))
#       5 display(latent_space.get_similar_genres_by_index(seed, similarity_measure='euclidean'))
#
# File ~/Documents/Flatiron/Projects/Music-Genre-Latent-Space/src/LatentSpace.py:113, in LatentSpace.get_similar_tracks_by_index(self, df_index, num, similarity_measure)
#     111 def get_similar_tracks_by_index(self, df_index, num=10, similarity_measure='cosine'):
# --> 113     track_similarity_df = self._get_similarity(self.tracks.iloc[[df_index]], self.tracks, subset=self.latent_cols, num=num, similarity_measure=similarity_measure)
#     115     return track_similarity_df[['track_name','artist_name', 'track_uri','similarity']]
#
# File ~/Documents/Flatiron/Projects/Music-Genre-Latent-Space/src/LatentSpace.py:141, in LatentSpace._get_similarity(self, df1, df2, subset, num, similarity_measure)
#     137     raise ValueError('similarity_measure must be "cosine" or "euclidean"')
#     139 similarity = similarity_measure_fn(np.array(df1[subset]), np.array(df2[subset]))
# --> 141 similarity_df = df2.deepcopy()
#     142 similarity_df['similarity'] = similarity.T
#     144 return similarity_df.sort_values(by='similarity', ascending=sort)[:num]
#
# File ~/miniforge3/envs/golden_env/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'deepcopy'

# %%
from pyarrow import feather
feather.read_feather('data/latent_space_save/artists.feather')
# Out:
#                      latent_0  latent_1  latent_2  latent_3  latent_4  \
# artist_name
# !!!                 -0.093092  0.273635 -0.359922  0.055348 -0.745507
# "Weird Al" Yankovic  0.341545  0.226364 -0.431828 -0.737806  1.033889
# #1 Dads              0.688585 -0.325864 -0.403679 -0.171223  0.147612
# #90s Update         -0.601853  0.760909 -0.229960  0.272182  0.333696
# #M P L S             0.057898 -0.027478 -0.111383 -0.339202  0.490447
# ...                       ...       ...       ...       ...       ...
# 트로트 가수들             -0.055655  0.135593 -0.545033  0.102071  0.173445
# 파니핑크                 0.833407 -0.240428 -0.082421  0.621003 -0.030435
# 패티김                  1.555425  0.157135  0.382276  0.166312 -1.162988
# 푸른새벽                 0.102385 -0.881505  0.437966  0.131330 -1.489592
# 플라워                  0.573591  0.466193  0.408668 -0.369388  0.914828
#
#                      latent_5  latent_6  latent_7  latent_8  latent_9  ...  \
# artist_name                                                            ...
# !!!                 -0.505306  0.388119 -0.094968 -0.160234 -0.064491  ...
# "Weird Al" Yankovic -0.306828 -0.000568  0.289829 -0.303757 -0.988815  ...
# #1 Dads             -0.539949 -0.416179  0.186194 -0.169721 -0.307046  ...
# #90s Update          0.217613  0.348038  0.308312 -0.258377  0.954199  ...
# #M P L S             0.264413  0.091633 -0.237328  1.008620 -0.354147  ...
# ...                       ...       ...       ...       ...       ...  ...
# 트로트 가수들             -0.433332 -0.236751 -0.162848 -0.394171 -0.139164  ...
# 파니핑크                -0.594916  0.105251 -0.840222  0.375992 -0.822308  ...
# 패티김                 -1.223127 -0.342458  0.060412  0.549998  0.474238  ...
# 푸른새벽                -0.355674 -0.685026  0.286568 -0.247291  0.436201  ...
# 플라워                  0.337832 -1.805027  0.210605  0.800312 -0.055374  ...
#
#                      latent_118  latent_119  latent_120  latent_121  \
# artist_name
# !!!                    0.381984    0.060424   -0.529038    0.032527
# "Weird Al" Yankovic    0.109830    1.422638    0.837454   -0.444964
# #1 Dads               -0.391773    0.616138   -0.160558   -0.380312
# #90s Update            0.522312    0.627956   -0.578197   -0.442360
# #M P L S              -0.104905    0.050863    0.211532    0.627698
# ...                         ...         ...         ...         ...
# 트로트 가수들               -0.565690    0.190121    0.009241    0.294647
# 파니핑크                  -0.351878    0.986316    0.467274    0.288985
# 패티김                   -1.825267    0.410207   -1.016812    0.375702
# 푸른새벽                  -0.625353    0.396986   -1.407856    0.013190
# 플라워                   -0.307995   -0.080116   -0.245216   -0.973371
#
#                      latent_122  latent_123  latent_124  latent_125  \
# artist_name
# !!!                    0.187413   -0.242615    0.271059    0.230804
# "Weird Al" Yankovic    0.005258    0.681249    0.206787    0.998370
# #1 Dads               -0.460960   -0.029136   -0.212427   -0.029432
# #90s Update            0.668299   -0.195950   -0.211039    0.324261
# #M P L S               0.401851    0.380693    0.395675    0.904276
# ...                         ...         ...         ...         ...
# 트로트 가수들                0.272876   -0.043947    0.573592    0.344783
# 파니핑크                  -0.055140   -0.265303   -0.706402    0.142739
# 패티김                   -0.374664    0.365698   -0.586565    0.210377
# 푸른새벽                  -0.509009    0.872610   -0.981351   -0.136199
# 플라워                   -0.126780   -0.400502    0.779326    0.627357
#
#                      latent_126  latent_127
# artist_name
# !!!                   -0.013089   -0.462809
# "Weird Al" Yankovic   -0.230414    0.246917
# #1 Dads                0.101394   -0.097789
# #90s Update            0.021071    0.713074
# #M P L S               0.081716    0.238920
# ...                         ...         ...
# 트로트 가수들               -0.505729   -0.661723
# 파니핑크                  -0.607964   -0.386149
# 패티김                   -0.346670    0.012528
# 푸른새벽                  -0.477512    0.471264
# 플라워                    0.172739   -0.274737
#
# [62542 rows x 128 columns]
