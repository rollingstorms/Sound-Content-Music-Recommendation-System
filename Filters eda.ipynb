# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
autoencoder_path = 'data/autoencoder_256dim_time_freq_128k_20epochs/'
autoencoder = tf.keras.models.load_model(autoencoder_path)

# %%
autoencoder.layers[1].layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x179bcb850>,
#  <keras.layers.core.dense.Dense at 0x179bcba30>,
#  <keras.layers.reshaping.reshape.Reshape at 0x179bd5040>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x179bd5340>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x179bd5af0>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x179bd5a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x179bddbb0>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x179bddaf0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x179be8c70>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x179be8bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x179bf1d30>,
#  <keras.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x179bf1c70>]

# %%
weights = autoencoder.layers[0].layers[4].get_weights()[0]

# %%
f_min, f_max = weights.min(), weights.max()
filters = (weights - f_min) / (f_max - f_min)

# %%
filters.shape
# Out:
# (5, 128, 32)

# %%
for i in range(filters.shape[2]):
    plt.figure(figsize=(10,5))
    plt.imshow(filters[:,:,i], aspect=4)
    plt.show()
